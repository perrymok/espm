# %% [markdown]
# # Version History
#
# This notebook is designed to present and test all the features of the different versions.

# %% [markdown]
# # 1. Version 1.1.4
#
# ## Update summary
#
# ### 1.1. Loading data

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# Generic imports 
import hyperspy.api as hs
import numpy as np

# espm imports
from espm.estimators import SmoothNMF
import espm.datasets as ds

# Generate the data
# Here `seeds_range` is the number of different samples to generate
ds.generate_built_in_datasets(seeds_range=1)

# Load the data
spim = ds.load_particules(sample = 0)
# We need to change the data to floats for the decomposition to run
spim.change_dtype('float64')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Generating 2 particles + one matrix built-in dataset. This will take a minute.
# 100%|██████████| 1/1 [00:00<00:00,  1.12it/s]
# Generating a grain boundary with Sr segregation. This will take a minute.
# 100%|██████████| 1/1 [00:11<00:00, 11.64s/it]

# %% [markdown]
# ### 1.2. cross sections utils

# %%
from espm.cross_sections_utils import modify_cross_sections

modify_cross_sections(100, input_type = 'scaling_factors', lines_scaling_factors = {'Ca_Ka' : 0.9, 'W_La1' : 1.1})
# Out:
# Applied scaling factor 0.9 to cross-section for element Ca, line Ka1
# Applied scaling factor 0.9 to cross-section for element Ca, line Ka2
# Skipped element Ca, line KL1: No matching data in database.
# Applied scaling factor 1.1 to cross-section for element W, line La1
